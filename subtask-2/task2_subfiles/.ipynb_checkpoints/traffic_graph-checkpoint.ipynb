# %%
import pandas as pd
data = pd.read_csv('out.txt',sep=' ',header=None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y = data[1]
z = data[2]
plt.setp(lines2, linewidth=2.0)
lines2=plt.plot(x, y,'b--', linestyle = "solid")
lines2=plt.plot(x, z, 'y--', linestyle = "solid")
plt.show()
